# %% [markdown]
# <a href="https://colab.research.google.com/github/z-guard/analysis/blob/main/notebooks/place_photo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 場所の写真
# - [場所を探す](https://developers.google.com/maps/documentation/places/web-service/search-find-place)
# - [場所の写真](https://developers.google.com/maps/documentation/places/web-service/photos)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import requests
import json
import pandas as pd
from urllib.parse import urlparse, quote
import io
import numpy as np
import glob

pd.set_option('display.max_columns', 50)
pd.set_option('display.max_rows', 100)

# %%
DIR_NAME = '/content/drive/MyDrive/z-gard/data'

# %% [markdown]
# ### 人口マスタ

# %%
df_pop_master = pd.read_csv(os.path.join(DIR_NAME, 'population_master.csv'))[['town_id', '市区町村名', '町名', '町丁目']]
print(df_pop_master.shape)
# Out:
# (3145, 4)

# %%
df_pop_master.head()
# Out:
#    town_id 市区町村名   町名     町丁目
# 0   101003  千代田区  丸の内  丸の内１丁目
# 1   101004  千代田区  丸の内  丸の内２丁目
# 2   101005  千代田区  丸の内  丸の内３丁目
# 3   101007  千代田区  大手町  大手町１丁目
# 4   101008  千代田区  大手町  大手町２丁目

# %%
# file_list = glob.glob(os.path.join(DIR_NAME, 'photo/*.jpg'))
# print(len(file_list))

# %%
# # 既に存在している写真のリスト
# df_exist_file = pd.DataFrame([int(os.path.splitext(os.path.basename(file))[0]) for file in file_list], columns=['file'])
# print(len(df_exist_file))

# df_pop_merge = pd.merge(df_pop_master, df_exist_file, left_on='地域ID', right_on='file', how='left')
# print(len(df_pop_merge))

# # 写真がない地域IDを抽出
# df_not_exist = df_pop_merge[df_pop_merge['file'].isna()].reset_index(drop=True)
# print(len(df_not_exist))

# %%
# df_not_exist.head()

# %%
YOUR_API_KEY = 'AIzaSyDbyTP873QCjlAnLtsz9vw42_Fc9iNaz9Q'

# %%
def get_place_info(place_name, unique_no):
    place = quote(place_name)
    url = f"https://maps.googleapis.com/maps/api/place/findplacefromtext/json?input={place}&inputtype=textquery&fields=name%2Cphoto%2Cgeometry&key={YOUR_API_KEY}"
    response = requests.get(url)
    if response.status_code == requests.codes.ok:
        try:
            _df = pd.DataFrame(response.json()['candidates'])
            _df['no'] = unique_no
            _df['place_name'] = place_name
            return _df
        except Exception as e:
            print(unique_no, place_name, e)
            pass
    else:
        print(unique_no, place_name, response.status_code)

    return pd.DataFrame([{'no': unique_no, 'place_name': place_name}])

# %%
df_place = pd.DataFrame()
for index, row in df_pop_master.iterrows():
    _df = get_place_info(row['市区町村名']+row['町丁目'], row['town_id'])
    df_place = pd.concat([df_place, _df])
df_place = df_place.reset_index(drop=True)
print(df_place.shape)
# Out:
# 121331 足立区六町３丁目 500
# (3153, 5)

# %%
df_place.head()
# Out:
#                                             geometry                name  \
# 0  {'location': {'lat': 35.6818718, 'lng': 139.76...  1 Chome Marunouchi
# 1  {'location': {'lat': 35.6796995, 'lng': 139.76...  2 Chome Marunouchi
# 2  {'location': {'lat': 35.6767681, 'lng': 139.76...  3 Chome Marunouchi
# 3  {'location': {'lat': 35.6877339, 'lng': 139.76...    1 Chome Ōtemachi
# 4  {'location': {'lat': 35.6863398, 'lng': 139.76...    2 Chome Ōtemachi
#
#                                               photos      no  place_name
# 0  [{'height': 4147, 'html_attributions': ['<a hr...  101003  千代田区丸の内１丁目
# 1  [{'height': 3000, 'html_attributions': ['<a hr...  101004  千代田区丸の内２丁目
# 2  [{'height': 3264, 'html_attributions': ['<a hr...  101005  千代田区丸の内３丁目
# 3  [{'height': 786, 'html_attributions': ['<a hre...  101007  千代田区大手町１丁目
# 4                                                NaN  101008  千代田区大手町２丁目

# %% [markdown]
# ### 重複している行

# %%
duplicate_no_list = list(df_place[df_place.duplicated(subset=['no'])]['no'].unique())
len(duplicate_no_list)
# Out:
# 9

# %%
df_dup = pd.DataFrame()
for no in duplicate_no_list:
    _tmp = df_place[df_place['no'] == no]
    _tmp_2 = _tmp[(_tmp['geometry'].notna())&(_tmp['photos'].notna())]
    if len(_tmp_2) > 0:
        df_dup = df_dup.append(_tmp_2.iloc[0], ignore_index=True)
    else:
        print(f'no data: {no}')
        df_dup = df_dup.append(_tmp.iloc[0], ignore_index=True)

print(df_dup.shape)
# Out:
# no data: 101066
# no data: 101099
# no data: 101101
# (9, 5)
# <ipython-input-22-b35cf07e7d6f>:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_dup = df_dup.append(_tmp_2.iloc[0], ignore_index=True)
# <ipython-input-22-b35cf07e7d6f>:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_dup = df_dup.append(_tmp.iloc[0], ignore_index=True)

# %%
df_place_all = pd.concat([
    df_place[~df_place['no'].isin(duplicate_no_list)],
    df_dup
]).sort_values('no').reset_index(drop=True)
print(df_place_all.shape)
# Out:
# (3144, 5)

# %%
df_place_all['no'] = df_place_all['no'].astype(int)

# %%
def get_geometry_lat(x):
    try:
        return x['location']['lat']
    except:
        return np.NaN

def get_geometry_lng(x):
    try:
        return x['location']['lng']
    except:
        return np.NaN

def get_photos_height(x):
    try:
        return x[0]['height']
    except:
        return np.NaN

def get_photos_width(x):
    try:
        return x[0]['width']
    except:
        return np.NaN

def get_photos_ref(x):
    try:
        return x[0]['photo_reference']
    except:
        return np.NaN

# %%
df_place_all['lat'] = df_place_all['geometry'].apply(get_geometry_lat)
df_place_all['lng'] = df_place_all['geometry'].apply(get_geometry_lng)
df_place_all['height'] = df_place_all['photos'].apply(get_photos_height)
df_place_all['width'] = df_place_all['photos'].apply(get_photos_width)
df_place_all['photo_reference'] = df_place_all['photos'].apply(get_photos_ref)

# %%
df_place_all = df_place_all.drop(columns=['geometry', 'photos', 'name'])

# %%
df_place_all.head()
# Out:
#        no  place_name        lat         lng  height   width  \
# 0  101003  千代田区丸の内１丁目  35.681872  139.765847  4147.0  5184.0
# 1  101004  千代田区丸の内２丁目  35.679699  139.763291  3000.0  5333.0
# 2  101005  千代田区丸の内３丁目  35.676768  139.764569  3264.0  2448.0
# 3  101007  千代田区大手町１丁目  35.687734  139.763291   786.0   664.0
# 4  101008  千代田区大手町２丁目  35.686340  139.768403     NaN     NaN
#
#                                      photo_reference
# 0  AWU5eFgpegrHL-hi5DhA9ZfsKZlNilcGtMKbk6coU9ir6z...
# 1  AWU5eFg91w8fI7kBiqMdn08yhPtVezrdniuHL76dW1IR0T...
# 2  AWU5eFh890yCHQBOZdYYG9DRVg-G3Yf-k1rNYi9NrEqXx8...
# 3  AWU5eFiec6gbMlqHVa_IITkrSpe327YqZfSZgcxpeg1aa-...
# 4                                                NaN

# %%
df_place_all.to_csv(os.path.join(DIR_NAME, 'place_photo_20231122.csv'), index=False)

# %%
def save_photo_image(photo_ref, width, id):
    url = f"https://maps.googleapis.com/maps/api/place/photo?maxwidth={width}&photo_reference={photo_ref}&key={YOUR_API_KEY}"
    response = requests.get(url)
    if response.status_code == requests.codes.ok:
        image = response.content
        filename = os.path.join(DIR_NAME, f'photo/{id}.jpg')
        with open(filename, "wb") as f:
            f.write(image)

# %%
# save_photo_count = 0
# no_photo_count = 0
# for index, row in df_place_all.iterrows():
#     photo_ref = row['photo_reference']
#     if not np.isnan(photo_ref):
#         width = int(row['width']) if row['width'] < 1000 else 1000
#         save_photo_image(photo_ref, width, row['no'])
#         save_photo_count += 1
#     else:
#         no_photo_count += 1

# print(f'save photo: {save_photo_count}, no photo: {no_photo_count}')
# Out:
# save photo: 401, no photo: 0

# %%
# photo_list = list(glob.glob(os.path.join(DIR_NAME, 'photo/*.jpg')))
# print(len(photo_list))
# Out:
# 3087

# %%
get_photo = df_place_all[df_place_all['photo_reference'].notna()]
print(len(get_photo))
# Out:
# 728

# %%
# 写真を取得できなかった場所のリスト
df_place_all[df_place_all['photo_reference'].isna()]
# Out:
#           no  place_name        lat         lng  height  width photo_reference
# 4     101008  千代田区大手町２丁目  35.686340  139.768403     NaN    NaN             NaN
# 6     101011  千代田区内幸町２丁目  35.670851  139.753389     NaN    NaN             NaN
# 9     101016  千代田区霞が関１丁目  35.674453  139.753069     NaN    NaN             NaN
# 11    101018  千代田区霞が関３丁目  35.671891  139.746682     NaN    NaN             NaN
# 13    101021  千代田区永田町２丁目  35.675580  139.741572     NaN    NaN             NaN
# ...      ...         ...        ...         ...     ...    ...             ...
# 3139  123235  江戸川区臨海町２丁目  35.650634  139.858566     NaN    NaN             NaN
# 3140  123236  江戸川区臨海町３丁目  35.648273  139.865606     NaN    NaN             NaN
# 3141  123237  江戸川区臨海町４丁目  35.646102  139.863046     NaN    NaN             NaN
# 3142  123238  江戸川区臨海町５丁目  35.645049  139.869766     NaN    NaN             NaN
# 3143  123239  江戸川区臨海町６丁目  35.643444  139.861091     NaN    NaN             NaN
#
# [2416 rows x 7 columns]

# %% [markdown]
# ### GCSにアップロード

# %%
# from google.cloud import storage, exceptions
# from google.oauth2 import service_account

# %%
# key_path = '/content/drive/MyDrive/key/z-gard-aff003f55fbb.json'
# credential = service_account.Credentials.from_service_account_file(key_path)

# project_id = 'z-gard'
# bucket_name = 'z-gard_town_images'
# client = storage.Client(project_id, credentials=credential)
# bucket = client.get_bucket(bucket_name)

# %%
# get_file_list = [f'/content/drive/MyDrive/z-gard/data/photo/{no}.jpg' for no in list(get_photo['no'])]

# %%
# for file_path in get_file_list:
#     file_name = os.path.basename(file_path)
#     blob = bucket.blob(file_name)
#     blob.upload_from_filename(file_path)
#     print(file_name)
# Out:
# 101014.jpg
# 101022.jpg
# 101025.jpg
# 101033.jpg
# 101034.jpg
# 101035.jpg
# 101036.jpg
# 101037.jpg
# 101038.jpg
# 101039.jpg
# 101040.jpg
# 101041.jpg
# 101042.jpg
# 101043.jpg
# 101093.jpg
# 101120.jpg
# 101121.jpg
# 101122.jpg
# 101123.jpg
# 101128.jpg
# 101129.jpg
# 101130.jpg
# 101131.jpg
# 101136.jpg
# 101142.jpg
# 101143.jpg
# 101144.jpg
# 101145.jpg
# 101146.jpg
# 101147.jpg
# 102002.jpg
# 102013.jpg
# 102022.jpg
# 102027.jpg
# 102036.jpg
# 102056.jpg
# 102057.jpg
# 102060.jpg
# 102061.jpg
# 102062.jpg
# 102066.jpg
# 102071.jpg
# 102075.jpg
# 102079.jpg
# 102084.jpg
# 102089.jpg
# 102090.jpg
# 102099.jpg
# 102105.jpg
# 102116.jpg
# 102118.jpg
# 103003.jpg
# 103023.jpg
# 103052.jpg
# 103053.jpg
# 103089.jpg
# 104007.jpg
# 104008.jpg
# 104009.jpg
# 104014.jpg
# 104015.jpg
# 104016.jpg
# 104017.jpg
# 104018.jpg
# 104019.jpg
# 104020.jpg
# 104021.jpg
# 104022.jpg
# 104023.jpg
# 104024.jpg
# 104027.jpg
# 104040.jpg
# 104045.jpg
# 104049.jpg
# 104050.jpg
# 104051.jpg
# 104052.jpg
# 104053.jpg
# 104054.jpg
# 104062.jpg
# 104063.jpg
# 104064.jpg
# 104065.jpg
# 104066.jpg
# 104067.jpg
# 104068.jpg
# 104069.jpg
# 104070.jpg
# 104071.jpg
# 104072.jpg
# 104073.jpg
# 104074.jpg
# 104075.jpg
# 104076.jpg
# 104077.jpg
# 104078.jpg
# 104079.jpg
# 104080.jpg
# 104081.jpg
# 104082.jpg
# 104083.jpg
# 104084.jpg
# 104085.jpg
# 104086.jpg
# 104087.jpg
# 104088.jpg
# 104089.jpg
# 104090.jpg
# 104091.jpg
# 104092.jpg
# 104093.jpg
# 104094.jpg
# 104095.jpg
# 104096.jpg
# 104097.jpg
# 104099.jpg
# 104102.jpg
# 104103.jpg
# 104104.jpg
# 104105.jpg
# 104106.jpg
# 104107.jpg
# 104108.jpg
# 104109.jpg
# 104110.jpg
# 104111.jpg
# 104112.jpg
# 104113.jpg
# 104114.jpg
# 104117.jpg
# 104119.jpg
# 104127.jpg
# 104128.jpg
# 104165.jpg
# 104172.jpg
# 105003.jpg
# 105006.jpg
# 105045.jpg
# 105047.jpg
# 106030.jpg
# 106047.jpg
# 106086.jpg
# 106093.jpg
# 106103.jpg
# 106128.jpg
# 106130.jpg
# 106135.jpg
# 107079.jpg
# 107098.jpg
# 108034.jpg
# 108047.jpg
# 108079.jpg
# 108098.jpg
# 108104.jpg
# 108105.jpg
# 108106.jpg
# 108115.jpg
# 108148.jpg
# 108162.jpg
# 108165.jpg
# 108197.jpg
# 109071.jpg
# 109102.jpg
# 109108.jpg
# 109157.jpg
# 109158.jpg
# 110014.jpg
# 110037.jpg
# 110040.jpg
# 110043.jpg
# 110067.jpg
# 110102.jpg
# 111040.jpg
# 111050.jpg
# 111051.jpg
# 111075.jpg
# 111109.jpg
# 111110.jpg
# 111111.jpg
# 111112.jpg
# 111113.jpg
# 111120.jpg
# 111169.jpg
# 111177.jpg
# 111186.jpg
# 111214.jpg
# 111260.jpg
# 111269.jpg
# 111273.jpg
# 112003.jpg
# 112043.jpg
# 112088.jpg
# 112115.jpg
# 112116.jpg
# 112122.jpg
# 112123.jpg
# 112147.jpg
# 112168.jpg
# 112203.jpg
# 112227.jpg
# 112249.jpg
# 112291.jpg
# 113009.jpg
# 113025.jpg
# 113026.jpg
# 113027.jpg
# 113028.jpg
# 113034.jpg
# 113035.jpg
# 113039.jpg
# 113040.jpg
# 113044.jpg
# 113045.jpg
# 113048.jpg
# 113049.jpg
# 113061.jpg
# 113062.jpg
# 114016.jpg
# 114019.jpg
# 114023.jpg
# 114046.jpg
# 114057.jpg
# 114071.jpg
# 115006.jpg
# 115022.jpg
# 115045.jpg
# 115046.jpg
# 115062.jpg
# 115159.jpg
# 116003.jpg
# 116017.jpg
# 116027.jpg
# 116100.jpg
# 117004.jpg
# 117081.jpg
# 117116.jpg
# 118023.jpg
# 118059.jpg
# 119010.jpg
# 119011.jpg
# 119012.jpg
# 119013.jpg
# 119014.jpg
# 119015.jpg
# 119016.jpg
# 119017.jpg
# 119018.jpg
# 119019.jpg
# 119020.jpg
# 119021.jpg
# 119022.jpg
# 119023.jpg
# 119024.jpg
# 119025.jpg
# 119026.jpg
# 119027.jpg
# 119028.jpg
# 119029.jpg
# 119030.jpg
# 119050.jpg
# 119059.jpg
# 119060.jpg
# 119061.jpg
# 119062.jpg
# 119063.jpg
# 119097.jpg
# 119121.jpg
# 119129.jpg
# 119140.jpg
# 119151.jpg
# 120008.jpg
# 120138.jpg
# 120182.jpg
# 120183.jpg
# 120191.jpg
# 120219.jpg
# 120235.jpg
# 120245.jpg
# 121024.jpg
# 121040.jpg
# 121053.jpg
# 121078.jpg
# 121081.jpg
# 121108.jpg
# 121120.jpg
# 121129.jpg
# 121131.jpg
# 121145.jpg
# 121146.jpg
# 121150.jpg
# 121151.jpg
# 121152.jpg
# 121156.jpg
# 121157.jpg
# 121158.jpg
# 121159.jpg
# 121160.jpg
# 121165.jpg
# 121166.jpg
# 121167.jpg
# 121201.jpg
# 121236.jpg
# 121256.jpg
# 121269.jpg
# 121275.jpg
# 121286.jpg
# 121307.jpg
# 121308.jpg
# 121309.jpg
# 121310.jpg
# 121314.jpg
# 121322.jpg
# 121327.jpg
# 121329.jpg
# 122020.jpg
# 122050.jpg
# 122069.jpg
# 122089.jpg
# 122090.jpg
# 122113.jpg
# 122125.jpg
# 122137.jpg
# 122149.jpg
# 122165.jpg
# 123037.jpg
# 123038.jpg
# 123050.jpg
# 123060.jpg
# 123088.jpg
# 123111.jpg
# 123121.jpg
# 123126.jpg
# 123135.jpg
# 123141.jpg
# 123153.jpg
# 123158.jpg
# 123163.jpg
# 123174.jpg
# 123183.jpg
# 123185.jpg
# 123198.jpg
# 123226.jpg
# 123229.jpg

# %%
# len([b for b in bucket.list_blobs()])
# Out:
# 3087

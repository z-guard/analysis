# %% [markdown]
# <a href="https://colab.research.google.com/github/z-guard/analysis/blob/main/notebooks/place_photo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 場所の写真
# - [場所を探す](https://developers.google.com/maps/documentation/places/web-service/search-find-place)
# - [場所の写真](https://developers.google.com/maps/documentation/places/web-service/photos)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import requests
import json
import pandas as pd
from urllib.parse import urlparse, quote
import io
import numpy as np
import glob

pd.set_option('display.max_columns', 50)
pd.set_option('display.max_rows', 100)

# %%
DIR_NAME = '/content/drive/MyDrive/z-gard/data'

# %% [markdown]
# ### 人口マスタ

# %%
df_pop_master = pd.read_csv(os.path.join(DIR_NAME, 'population_master.csv'))[['town_id', '市区町村名', '町名', '町丁目']]
print(df_pop_master.shape)
# Out:
# (3145, 4)

# %%
df_pop_master.head()
# Out:
#    town_id 市区町村名   町名     町丁目
# 0   101003  千代田区  丸の内  丸の内１丁目
# 1   101004  千代田区  丸の内  丸の内２丁目
# 2   101005  千代田区  丸の内  丸の内３丁目
# 3   101007  千代田区  大手町  大手町１丁目
# 4   101008  千代田区  大手町  大手町２丁目

# %%
# file_list = glob.glob(os.path.join(DIR_NAME, 'photo/*.jpg'))
# print(len(file_list))

# %%
# # 既に存在している写真のリスト
# df_exist_file = pd.DataFrame([int(os.path.splitext(os.path.basename(file))[0]) for file in file_list], columns=['file'])
# print(len(df_exist_file))

# df_pop_merge = pd.merge(df_pop_master, df_exist_file, left_on='地域ID', right_on='file', how='left')
# print(len(df_pop_merge))

# # 写真がない地域IDを抽出
# df_not_exist = df_pop_merge[df_pop_merge['file'].isna()].reset_index(drop=True)
# print(len(df_not_exist))

# %%
# df_not_exist.head()

# %%
YOUR_API_KEY = ''

# %%
# %%time
# tmp_place_name = '港区元赤坂１丁目にある名所'
# place = quote(tmp_place_name)
# url = f"https://maps.googleapis.com/maps/api/place/findplacefromtext/json?input={place}&inputtype=textquery&fields=name%2Cphoto&language=ja&key={YOUR_API_KEY}"
# response = requests.get(url)
# if response.status_code == requests.codes.ok:
#     tmp_photo_reference = response.json()['candidates'][0]['photos'][0]['photo_reference']
#     print(tmp_photo_reference)

# response.json()

# %%
def get_place_info(place_name, unique_no):
    place = quote(place_name + 'にある名所')
    url = f"https://maps.googleapis.com/maps/api/place/findplacefromtext/json?input={place}&inputtype=textquery&fields=name%2Cphoto&language=ja&key={YOUR_API_KEY}"
    response = requests.get(url)
    if response.status_code == requests.codes.ok:
        try:
            _df = pd.DataFrame(response.json()['candidates'])
            _df['no'] = unique_no
            _df['place_name'] = place_name
            return _df
        except Exception as e:
            print(unique_no, place_name, e)
            pass
    else:
        print(unique_no, place_name, response.status_code)

    return pd.DataFrame([{'no': unique_no, 'place_name': place_name}])

# %%
df_place = pd.DataFrame()
for index, row in df_pop_master.iterrows():
    _df = get_place_info(row['市区町村名']+row['町丁目'], row['town_id'])
    df_place = pd.concat([df_place, _df])
df_place = df_place.reset_index(drop=True)
print(df_place.shape)
# Out:
# (3193, 4)

# %%
df_place.head()
# Out:
#            name                                             photos      no  \
# 0    東京駅丸の内駅前広場  [{'height': 1080, 'html_attributions': ['<a hr...  101003
# 1     丸の内ラグビー神社  [{'height': 3000, 'html_attributions': ['<a hr...  101004
# 2  浅草寺・雷門モニュメント                                                NaN  101005
# 3           大手濠  [{'height': 1944, 'html_attributions': ['<a hr...  101007
# 4         巨大赤べこ  [{'height': 3000, 'html_attributions': ['<a hr...  101008
#
#    place_name
# 0  千代田区丸の内１丁目
# 1  千代田区丸の内２丁目
# 2  千代田区丸の内３丁目
# 3  千代田区大手町１丁目
# 4  千代田区大手町２丁目

# %% [markdown]
# ### 重複している行

# %%
duplicate_no_list = list(df_place[df_place.duplicated(subset=['no'])]['no'].unique())
len(duplicate_no_list)
# Out:
# 20

# %%
df_dup = pd.DataFrame()
for no in duplicate_no_list:
    _tmp = df_place[df_place['no'] == no]
    _tmp_2 = _tmp[(_tmp['name'].notna())&(_tmp['photos'].notna())]
    if len(_tmp_2) > 0:
        df_dup = df_dup.append(_tmp_2.iloc[0], ignore_index=True)
    else:
        print(f'no data: {no}')
        df_dup = df_dup.append(_tmp.iloc[0], ignore_index=True)

print(df_dup.shape)
# Out:
# no data: 103092
# (20, 4)
# <ipython-input-69-085031ae6038>:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_dup = df_dup.append(_tmp_2.iloc[0], ignore_index=True)
# <ipython-input-69-085031ae6038>:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_dup = df_dup.append(_tmp.iloc[0], ignore_index=True)

# %%
df_place_all = pd.concat([
    df_place[~df_place['no'].isin(duplicate_no_list)],
    df_dup
]).sort_values('no').reset_index(drop=True)
print(df_place_all.shape)
# Out:
# (3145, 4)

# %%
df_place_all['no'] = df_place_all['no'].astype(int)

# %%
# def get_geometry_lat(x):
#     try:
#         return x['location']['lat']
#     except:
#         return np.NaN

# def get_geometry_lng(x):
#     try:
#         return x['location']['lng']
#     except:
#         return np.NaN

def get_photos_height(x):
    try:
        return x[0]['height']
    except:
        return np.NaN

def get_photos_width(x):
    try:
        return x[0]['width']
    except:
        return np.NaN

def get_photos_ref(x):
    try:
        return x[0]['photo_reference']
    except:
        return np.NaN

# %%
# df_place_all['lat'] = df_place_all['geometry'].apply(get_geometry_lat)
# df_place_all['lng'] = df_place_all['geometry'].apply(get_geometry_lng)
df_place_all['height'] = df_place_all['photos'].apply(get_photos_height)
df_place_all['width'] = df_place_all['photos'].apply(get_photos_width)
df_place_all['photo_reference'] = df_place_all['photos'].apply(get_photos_ref)

# %%
df_place_all = df_place_all.drop(columns=['photos'])

# %%
df_place_all.head()
# Out:
#            name      no  place_name  height   width  \
# 0    東京駅丸の内駅前広場  101003  千代田区丸の内１丁目  1080.0  1080.0
# 1     丸の内ラグビー神社  101004  千代田区丸の内２丁目  3000.0  4000.0
# 2  浅草寺・雷門モニュメント  101005  千代田区丸の内３丁目     NaN     NaN
# 3           大手濠  101007  千代田区大手町１丁目  1944.0  2592.0
# 4         巨大赤べこ  101008  千代田区大手町２丁目  3000.0  4000.0
#
#                                      photo_reference
# 0  AWU5eFgPasDCEmZ_Jfx7lw_DOiYJEwQO5C2sf_oYlTjQ-Z...
# 1  AWU5eFhq6XsspnuhJLOH9kJZmlZjy_nSzBQG9HT4YznIFg...
# 2                                                NaN
# 3  AWU5eFgr5mkU2W2MvOvRP453JPg5uVHpnua87f89NLvfvz...
# 4  AWU5eFhx7PSuwEfB9W40MGO7TESt5VKVS0RRpuvBoUrgOB...

# %%
df_place_all.to_csv(os.path.join(DIR_NAME, 'place_photo_20231122_2.csv'), index=False)

# %%
def save_photo_image(photo_ref, width, id):
    url = f"https://maps.googleapis.com/maps/api/place/photo?maxwidth={width}&photo_reference={photo_ref}&key={YOUR_API_KEY}"
    response = requests.get(url)
    if response.status_code == requests.codes.ok:
        image = response.content
        filename = os.path.join(DIR_NAME, f'photo/{id}.jpg')
        with open(filename, "wb") as f:
            f.write(image)

# %%
# save_photo_image(tmp_photo_reference, 1000, tmp_place_name)

# %%
# save_photo_count = 0
# no_photo_count = 0
# for index, row in df_place_all.iterrows():
#     photo_ref = row['photo_reference']
#     if not np.isnan(photo_ref):
#         width = int(row['width']) if row['width'] < 1000 else 1000
#         save_photo_image(photo_ref, width, row['no'])
#         save_photo_count += 1
#     else:
#         no_photo_count += 1

# print(f'save photo: {save_photo_count}, no photo: {no_photo_count}')

# %%
# photo_list = list(glob.glob(os.path.join(DIR_NAME, 'photo/*.jpg')))
# print(len(photo_list))

# %%
get_photo = df_place_all[df_place_all['photo_reference'].notna()]
print(len(get_photo))
# Out:
# 3058

# %%
# 写真を取得できなかった場所のリスト
df_place_all[df_place_all['photo_reference'].isna()]
# Out:
#                                 name      no   place_name  height  width  \
# 2                       浅草寺・雷門モニュメント  101005   千代田区丸の内３丁目     NaN    NaN
# 92                             神田富山町  101122    千代田区神田富山町     NaN    NaN
# 112                         神田佐久間町河岸  101145  千代田区神田佐久間河岸     NaN    NaN
# 119                温泉の活用、温泉関連商品の研究開発  102008     中央区銀座１丁目     NaN    NaN
# 178                           日本橋馬喰町  102081   中央区東日本橋１丁目     NaN    NaN
# 180                           日本橋馬喰町  102083   中央区東日本橋３丁目     NaN    NaN
# 235                          太閤千代しだれ  103029      港区三田３丁目     NaN    NaN
# 238                             増上寺碑  103033     港区浜松町１丁目     NaN    NaN
# 239                             増上寺碑  103034     港区浜松町２丁目     NaN    NaN
# 250                          晚上の東京鐵塔  103048     港区虎ノ門５丁目     NaN    NaN
# 261                         麻布十番の河津桜  103062     港区元麻布２丁目     NaN    NaN
# 277                         麻布十番の河津桜  103082    港区麻布十番１丁目     NaN    NaN
# 278                         麻布十番の河津桜  103083    港区麻布十番２丁目     NaN    NaN
# 279                         麻布十番の河津桜  103084    港区麻布十番３丁目     NaN    NaN
# 284                        豊川稲荷縁起説明板  103091     港区元赤坂１丁目     NaN    NaN
# 285                       Chikuyurin  103092     港区元赤坂２丁目     NaN    NaN
# 288                     赤坂氷川山車展示スペース  103096      港区赤坂３丁目     NaN    NaN
# 289                     赤坂氷川山車展示スペース  103097      港区赤坂４丁目     NaN    NaN
# 294                              木の木  103102      港区赤坂９丁目     NaN    NaN
# 340           Your name Street Scene  104012     新宿区若葉２丁目     NaN    NaN
# 375                            市谷鷹匠町  104052     新宿区市谷鷹匠町     NaN    NaN
# 543                             きつね坂  105079    文京区千駄木３丁目     NaN    NaN
# 544                             きつね坂  105080    文京区千駄木４丁目     NaN    NaN
# 628                        花川戸一丁目休憩所  106100    台東区花川戸１丁目     NaN    NaN
# 659                  谷中名水「バケツ・リレー井戸」  106141     台東区谷中７丁目     NaN    NaN
# 680                           ダービー通り  107028    墨田区江東橋３丁目     NaN    NaN
# 705                       タワービュー通り看板  107060     墨田区錦糸２丁目     NaN    NaN
# 710                          金糸のオブジェ  107066     墨田区太平３丁目     NaN    NaN
# 711                          金糸のオブジェ  107067     墨田区太平４丁目     NaN    NaN
# 721   photography’s place of Skytree  107079     墨田区業平５丁目     NaN    NaN
# 818                             中央広場  108075     江東区豊洲２丁目     NaN    NaN
# 820                             中央広場  108077     江東区豊洲４丁目     NaN    NaN
# 918                           岩のオブジェ  108196     江東区若洲３丁目     NaN    NaN
# 1080                         権之助坂表示杭  110040    目黒区下目黒１丁目     NaN    NaN
# 1081                         権之助坂表示杭  110041    目黒区下目黒２丁目     NaN    NaN
# 1237                            武隈部屋  111120     大田区雪谷大塚町     NaN    NaN
# 1270                            武隈部屋  111163    大田区南雪谷４丁目     NaN    NaN
# 1274                             稲荷坂  111168    大田区上池台３丁目     NaN    NaN
# 1275                             稲荷坂  111169    大田区上池台４丁目     NaN    NaN
# 1276                             稲荷坂  111170    大田区上池台５丁目     NaN    NaN
# 1289                       Tram view  111186      大田区羽田旭町     NaN    NaN
# 1293                       Tram view  111191     大田区羽田４丁目     NaN    NaN
# 1354                       Tram view  111269     大田区羽田沖水面     NaN    NaN
# 1367                     三軒茶屋地名由来説明板  112014   世田谷区太子堂４丁目     NaN    NaN
# 1369                     三軒茶屋地名由来説明板  112017  世田谷区三軒茶屋１丁目     NaN    NaN
# 1370                     三軒茶屋地名由来説明板  112018  世田谷区三軒茶屋２丁目     NaN    NaN
# 1388                         カラフルアート  112041    世田谷区経堂１丁目     NaN    NaN
# 1389                         カラフルアート  112042    世田谷区経堂２丁目     NaN    NaN
# 1436              せたがや百景「10北沢八幡の秋祭り」  112099    世田谷区代沢５丁目     NaN    NaN
# 1637                         プラタナス広場  113005    渋谷区恵比寿３丁目     NaN    NaN
# 1638                         プラタナス広場  113006    渋谷区恵比寿４丁目     NaN    NaN
# 1645                             緑萼梅  113015      渋谷区東２丁目     NaN    NaN
# 1647                             緑萼梅  113017      渋谷区東４丁目     NaN    NaN
# 1711                        神宮イチョウ並木  113097    渋谷区神宮前３丁目     NaN    NaN
# 1814                            勧学の碑  115020     杉並区永福４丁目     NaN    NaN
# 1829                            勧学の碑  115040     杉並区大宮２丁目     NaN    NaN
# 1834                            高南通り  115047   杉並区高円寺南３丁目     NaN    NaN
# 2023                        北区稲荷前ガード  117004      北区王子２丁目     NaN    NaN
# 2039                        北区稲荷前ガード  117022      北区堀船４丁目     NaN    NaN
# 2105                     滝野川狐塚の坂（道標）  117106     北区滝野川３丁目     NaN    NaN
# 2106                     滝野川狐塚の坂（道標）  117107     北区滝野川４丁目     NaN    NaN
# 2107                     滝野川狐塚の坂（道標）  117108     北区滝野川５丁目     NaN    NaN
# 2148                   荒川六丁目グリーンスポット  118017     荒川区荒川６丁目     NaN    NaN
# 2151                   町屋三丁目グリーンスポット  118021     荒川区町屋１丁目     NaN    NaN
# 2152                   町屋三丁目グリーンスポット  118022     荒川区町屋２丁目     NaN    NaN
# 2153                   町屋三丁目グリーンスポット  118023     荒川区町屋３丁目     NaN    NaN
# 2159                   東尾久一丁目西防災スポット  118030    荒川区東尾久１丁目     NaN    NaN
# 2169                  西尾久六丁目グリーンスポット  118041    荒川区西尾久３丁目     NaN    NaN
# 2171                  西尾久五丁目グリーンスポット  118043    荒川区西尾久５丁目     NaN    NaN
# 2173                  西尾久五丁目グリーンスポット  118045    荒川区西尾久７丁目     NaN    NaN
# 2174                  西尾久五丁目グリーンスポット  118046    荒川区西尾久８丁目     NaN    NaN
# 2213                             地蔵坂  119030     板橋区大谷口北町     NaN    NaN
# 2214                             地蔵坂  119032    板橋区大谷口１丁目     NaN    NaN
# 2215                             地蔵坂  119033    板橋区大谷口２丁目     NaN    NaN
# 2216                             地蔵坂  119035     板橋区向原１丁目     NaN    NaN
# 2217                             地蔵坂  119036     板橋区向原２丁目     NaN    NaN
# 2218                             地蔵坂  119037     板橋区向原３丁目     NaN    NaN
# 2390                     練馬小学校南 横断歩道  120090    練馬区春日町４丁目     NaN    NaN
# 2392                     練馬小学校南 横断歩道  120092    練馬区春日町６丁目     NaN    NaN
# 2513                          宇宙船ポッド  120235    練馬区大泉町６丁目     NaN    NaN
# 2545                         河村瑞賢追憶碑  121029   足立区伊興本町１丁目     NaN    NaN
# 2546                         河村瑞賢追憶碑  121030   足立区伊興本町２丁目     NaN    NaN
# 2735                         河村瑞賢追憶碑  121263    足立区東伊興２丁目     NaN    NaN
# 2736                         河村瑞賢追憶碑  121264    足立区東伊興３丁目     NaN    NaN
# 2737                         河村瑞賢追憶碑  121265    足立区東伊興４丁目     NaN    NaN
# 2771                         本木西児童遊園  121308      足立区本木西町     NaN    NaN
# 3070                       篠崎公園 16号地  123151   江戸川区篠崎町７丁目     NaN    NaN
#
#      photo_reference
# 2                NaN
# 92               NaN
# 112              NaN
# 119              NaN
# 178              NaN
# 180              NaN
# 235              NaN
# 238              NaN
# 239              NaN
# 250              NaN
# 261              NaN
# 277              NaN
# 278              NaN
# 279              NaN
# 284              NaN
# 285              NaN
# 288              NaN
# 289              NaN
# 294              NaN
# 340              NaN
# 375              NaN
# 543              NaN
# 544              NaN
# 628              NaN
# 659              NaN
# 680              NaN
# 705              NaN
# 710              NaN
# 711              NaN
# 721              NaN
# 818              NaN
# 820              NaN
# 918              NaN
# 1080             NaN
# 1081             NaN
# 1237             NaN
# 1270             NaN
# 1274             NaN
# 1275             NaN
# 1276             NaN
# 1289             NaN
# 1293             NaN
# 1354             NaN
# 1367             NaN
# 1369             NaN
# 1370             NaN
# 1388             NaN
# 1389             NaN
# 1436             NaN
# 1637             NaN
# 1638             NaN
# 1645             NaN
# 1647             NaN
# 1711             NaN
# 1814             NaN
# 1829             NaN
# 1834             NaN
# 2023             NaN
# 2039             NaN
# 2105             NaN
# 2106             NaN
# 2107             NaN
# 2148             NaN
# 2151             NaN
# 2152             NaN
# 2153             NaN
# 2159             NaN
# 2169             NaN
# 2171             NaN
# 2173             NaN
# 2174             NaN
# 2213             NaN
# 2214             NaN
# 2215             NaN
# 2216             NaN
# 2217             NaN
# 2218             NaN
# 2390             NaN
# 2392             NaN
# 2513             NaN
# 2545             NaN
# 2546             NaN
# 2735             NaN
# 2736             NaN
# 2737             NaN
# 2771             NaN
# 3070             NaN

# %% [markdown]
# ### GCSにアップロード

# %%
# from google.cloud import storage, exceptions
# from google.oauth2 import service_account

# %%
# key_path = '/content/drive/MyDrive/key/z-gard-aff003f55fbb.json'
# credential = service_account.Credentials.from_service_account_file(key_path)

# project_id = 'z-gard'
# bucket_name = 'z-gard_town_images'
# client = storage.Client(project_id, credentials=credential)
# bucket = client.get_bucket(bucket_name)

# %%
# get_file_list = [f'/content/drive/MyDrive/z-gard/data/photo/{no}.jpg' for no in list(get_photo['no'])]

# %%
# for file_path in get_file_list:
#     file_name = os.path.basename(file_path)
#     blob = bucket.blob(file_name)
#     blob.upload_from_filename(file_path)
#     print(file_name)

# %%
# len([b for b in bucket.list_blobs()])
